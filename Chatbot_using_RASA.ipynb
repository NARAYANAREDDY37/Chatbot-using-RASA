# %% [markdown]
# <a href="https://colab.research.google.com/github/NARAYANAREDDY37/Chatbot-using-RASA/blob/main/Chatbot_using_RASA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rasa
# Out:
# ...
#      |████████████████████████████████| 655kB 8.1MB/s
# ...
#      |████████████████████████████████| 40kB 6.3MB/s
# ...
#      |████████████████████████████████| 61kB 8.8MB/s
# ...
#      |████████████████████████████████| 1.1MB 17.1MB/s
# ...
#      |████████████████████████████████| 256kB 29.3MB/s
# ...
#      |████████████████████████████████| 184kB 38.5MB/s
# ...
#      |████████████████████████████████| 112kB 41.1MB/s
# ...
#      |████████████████████████████████| 102kB 12.7MB/s
# ...
#      |████████████████████████████████| 378kB 31.1MB/s
# ...
#      |████████████████████████████████| 51kB 8.0MB/s
# ...
#      |████████████████████████████████| 3.0MB 46.2MB/s
# ...
#      |████████████████████████████████| 112kB 44.0MB/s
# ...
#      |████████████████████████████████| 51kB 9.1MB/s
# ...
#      |████████████████████████████████| 133kB 53.3MB/s
# ...
#      |████████████████████████████████| 512kB 53.2MB/s
# ...
#      |████████████████████████████████| 307kB 52.2MB/s
# ...
#      |████████████████████████████████| 348kB 54.7MB/s
# ...

# %%
# !pwd
# Out:
# /content

# %%
# !rasa init --no-prompt
# Out:
# Welcome to Rasa! 🤖
#
# To get started quickly, an initial project will be created.
# If you need some help, check out the documentation at https://rasa.com/docs/rasa.
#
# Created project directory at '/content'.
# Finished creating project structure.
# Training an initial model...
# The configuration for policies and pipeline was chosen automatically. It was written into the config file at './config.yml'.
# Training NLU model...
# 2020-12-05 14:26:39 INFO     rasa.shared.nlu.training_data.training_data  - Training data stats:
# 2020-12-05 14:26:39 INFO     rasa.shared.nlu.training_data.training_data  - Number of intent examples: 69 (7 distinct intents)
#
# 2020-12-05 14:26:39 INFO     rasa.shared.nlu.training_data.training_data  -   Found intents: 'deny', 'mood_great', 'mood_unhappy', 'bot_challenge', 'goodbye', 'affirm', 'greet'
# 2020-12-05 14:26:39 INFO     rasa.shared.nlu.training_data.training_data  - Number of response examples: 0 (0 distinct responses)
# ...

# %%
# !rasa shell
# Out:
# 2020-12-05 14:34:58 INFO     rasa.model  - Loading model models/20201205-142638.tar.gz...
# 2020-12-05 14:34:59 INFO     root  - Connecting to channel 'cmdline' which was specified by the '--connector' argument. Any other channels will be ignored. To connect to all given channels, omit the '--connector' argument.
# 2020-12-05 14:34:59 INFO     root  - Starting Rasa server on http://localhost:5005
# 2020-12-05 14:34:59 INFO     rasa.model  - Loading model models/20201205-142638.tar.gz...
# 2020-12-05 14:35:07 INFO     root  - Rasa server is up and running.
# Bot loaded. Type a message and press enter (use '/stop' to exit):
# WARNING: your terminal doesn't support cursor position requests (CPR).
#
# Hey! How are you?
# WARNING: your terminal doesn't support cursor position requests (CPR).
#
# Great, carry on!
# WARNING: your terminal doesn't support cursor position requests (CPR).
#
# Hey! How are you?
# WARNING: your terminal doesn't support cursor position requests (CPR).
#
# ...
